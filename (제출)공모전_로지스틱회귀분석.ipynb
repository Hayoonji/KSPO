# %%
import pandas as pd
sports = pd.read_csv("2021국민생활체육조사_사용칼럼.csv")
sports=sports.dropna(axis=0)
sports=sports.astype('int')
sports
# Out:
#       LOC1  SEX  AGE  Q03  Q051  Q07  Q08  Q11  Q12  Q131  Q14  Q32  Q351  \
# 0        1    2   16    4     3    1    4    1    2     6    1    5     5
# 1        1    1   86    3     4    1    1    2    2     1    2    6     4
# 2        1    1   28    4     2    2    7    2    2     2    2    1     4
# 3        1    2   50    3     4    1    1    2    2     1    2    5     4
# 4        1    2   82    2     5    1    7    2    2     1    2    7     4
# ...    ...  ...  ...  ...   ...  ...  ...  ...  ...   ...  ...  ...   ...
# 8993    17    1   56    3     1    2    7    2    2     1    2    1     2
# 8994    17    1   46    4     4    1    2    1    2     1    2    6     4
# 8995    17    1   60    4     4    1    1    2    2     2    2    6     4
# 8996    17    2   54    3     4    2    6    2    2     5    2    3     5
# 8997    17    1   54    3     4    2    6    2    2     5    2    3     5
#
#       Q352  SEX.1  Q07_b  Q11_b  Q12_b  Q14_b  Q32_b
# 0        5      1      1      1      0      1      1
# 1        4      0      1      0      0      0      1
# 2        4      0      0      0      0      0      0
# 3        4      1      1      0      0      0      1
# 4        4      1      1      0      0      0      1
# ...    ...    ...    ...    ...    ...    ...    ...
# 8993     2      0      0      0      0      0      0
# 8994     3      0      1      1      0      0      1
# 8995     2      0      1      0      0      0      1
# 8996     4      1      0      0      0      0      1
# 8997     4      0      0      0      0      0      1
#
# [8998 rows x 20 columns]

# %%
features=sports[['Q07_b','SEX','AGE','Q11_b','Q12_b','Q051','Q14_b']]
know=sports['Q32_b']

from sklearn.model_selection import train_test_split
train_features, test_features, train_labels, test_labels = train_test_split(features, know)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_features = scaler.fit_transform(train_features)
test_features = scaler.transform(test_features)

# %% [markdown]
# ### 로지스틱 회귀분석

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(train_features, train_labels)
# Out:
# LogisticRegression()

# %%
print(model.score(train_features, train_labels))
print(model.score(test_features, test_labels))
# Out:
# 0.8310610551274452
# 0.8462222222222222

# %% [markdown]
# ### OLS분석

# %%
import statsmodels.api as sm
X_train_add_constant=sm.add_constant(train_features)
sm_lr_ac=sm.OLS(train_labels,X_train_add_constant).fit()
sm_lr_ac.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Q32_b   R-squared:                       0.416
# Model:                            OLS   Adj. R-squared:                  0.415
# Method:                 Least Squares   F-statistic:                     686.0
# Date:                Fri, 18 Nov 2022   Prob (F-statistic):               0.00
# Time:                        23:28:34   Log-Likelihood:                -2842.6
# No. Observations:                6748   AIC:                             5701.
# Df Residuals:                    6740   BIC:                             5756.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6310      0.004    140.491      0.000       0.622       0.640
# x1             0.0522      0.005     11.321      0.000       0.043       0.061
# x2             0.0114      0.005      2.508      0.012       0.002       0.020
# x3             0.0187      0.005      4.090      0.000       0.010       0.028
# x4             0.0540      0.005     10.602      0.000       0.044       0.064
# x5             0.0134      0.005      2.733      0.006       0.004       0.023
# x6             0.2738      0.005     57.378      0.000       0.264       0.283
# x7             0.0089      0.005      1.861      0.063      -0.000       0.018
# ==============================================================================
# Omnibus:                      207.509   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              226.459
# Skew:                          -0.447   Prob(JB):                     6.69e-50
# Kurtosis:                       2.927   Cond. No.                         1.80
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ###  로지스틱 최적화 기법으로 오즈비 찾기

# %%
logit=sm.Logit(train_labels,X_train_add_constant)
results=logit.fit()
results.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.409486
#          Iterations 7
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                          Results: Logit
# ================================================================
# Model:              Logit            Pseudo R-squared: 0.378
# Dependent Variable: Q32_b            AIC:              5542.4175
# Date:               2022-11-18 23:29 BIC:              5596.9535
# No. Observations:   6748             Log-Likelihood:   -2763.2
# Df Model:           7                LL-Null:          -4443.0
# Df Residuals:       6740             LLR p-value:      0.0000
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     7.0000
# ------------------------------------------------------------------
#            Coef.    Std.Err.      z      P>|z|     [0.025   0.975]
# ------------------------------------------------------------------
# const      0.8488     0.0369   23.0274   0.0000    0.7765   0.9210
# x1         0.3574     0.0357    9.9990   0.0000    0.2874   0.4275
# x2         0.0763     0.0342    2.2324   0.0256    0.0093   0.1433
# x3         0.1131     0.0343    3.2955   0.0010    0.0458   0.1804
# x4         0.4770     0.0437   10.9279   0.0000    0.3915   0.5626
# x5         0.2270     0.0559    4.0626   0.0000    0.1175   0.3365
# x6         1.7119     0.0451   37.9758   0.0000    1.6235   1.8002
# x7         0.0612     0.0397    1.5394   0.1237   -0.0167   0.1390
# ================================================================
#
# """

# %%
import numpy as np
np.exp(results.params)
# Out:
# const    2.336782
# x1       1.429625
# x2       1.079276
# x3       1.119783
# x4       1.611251
# x5       1.254801
# x6       5.539353
# x7       1.063060
# dtype: float64
